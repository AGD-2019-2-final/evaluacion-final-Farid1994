# %%
# %load_ext bigdata
# %pig_start
# %timeout 300

# %%
# %%pig
# u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
# t1= FOREACH u GENERATE $2;
# result= FILTER t1 BY $0 MATCHES 'D.*' OR surname MATCHES 'E.*' OR surname MATCHES 'F.*' OR surname MATCHES 'G.*' OR surname MATCHES 'H.*' OR surname MATCHES 'I.*' OR surname MATCHES 'J.*' OR surname MATCHES 'K.*';
# DUMP result;
# Out:
#  u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
#  t1= FOREACH u GENERATE $2;
# HES 'I.*' OR surname MATCHES 'J.*' OR surname MATCHES 'K.*';H.*' OR surname MATC
#  DUMP result;
# 2020-02-15 18:06:56,052 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - session.id is deprecated. Instead, use dfs.metrics.session-id
# 2020-02-15 18:06:56,054 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Initializing JVM Metrics with processName=JobTracker, sessionId=
# 2020-02-15 18:06:56,091 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-02-15 18:06:56,095 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2020-02-15 18:06:56,107 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.submit.replication is deprecated. Instead, use mapreduce.client.submit.file.replication
# 2020-02-15 18:06:56,245 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker.http.address is deprecated. Instead, use mapreduce.jobtracker.http.address
# 2020-02-15 18:06:56,256 [JobControl] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:06:56,275 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2020-02-15 18:06:56,338 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-02-15 18:06:56,429 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-02-15 18:06:56,462 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-02-15 18:06:56,604 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local123132353_0001
# 2020-02-15 18:06:56,988 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1581790016714/pig-0.17.0-core-h2.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/pig-0.17.0-core-h2.jar
# 2020-02-15 18:06:57,000 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1581790016714/pig-0.17.0-core-h2.jar /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/pig-0.17.0-core-h2.jar' failed 1 with: ln: failed to create symbolic link '/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/pig-0.17.0-core-h2.jar': Protocol error
#
# 2020-02-15 18:06:57,001 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1581790016714/pig-0.17.0-core-h2.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/pig-0.17.0-core-h2.jar
# 2020-02-15 18:06:57,002 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp183433602/tmp1526383685/pig-0.17.0-core-h2.jar as file:/tmp/hadoop-root/mapred/local/1581790016714/pig-0.17.0-core-h2.jar
# 2020-02-15 18:06:57,004 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1581790016715/automaton-1.11-8.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/automaton-1.11-8.jar
# 2020-02-15 18:06:57,010 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1581790016715/automaton-1.11-8.jar /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/automaton-1.11-8.jar' failed 1 with: ln: failed to create symbolic link '/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/automaton-1.11-8.jar': Protocol error
#
# 2020-02-15 18:06:57,011 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1581790016715/automaton-1.11-8.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/automaton-1.11-8.jar
# 2020-02-15 18:06:57,011 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp183433602/tmp701391624/automaton-1.11-8.jar as file:/tmp/hadoop-root/mapred/local/1581790016715/automaton-1.11-8.jar
# 2020-02-15 18:06:57,012 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1581790016716/antlr-runtime-3.4.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/antlr-runtime-3.4.jar
# 2020-02-15 18:06:57,020 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1581790016716/antlr-runtime-3.4.jar /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/antlr-runtime-3.4.jar' failed 1 with: ln: failed to create symbolic link '/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/antlr-runtime-3.4.jar': Protocol error
#
# 2020-02-15 18:06:57,020 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1581790016716/antlr-runtime-3.4.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/antlr-runtime-3.4.jar
# 2020-02-15 18:06:57,020 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp183433602/tmp-1575720804/antlr-runtime-3.4.jar as file:/tmp/hadoop-root/mapred/local/1581790016716/antlr-runtime-3.4.jar
# 2020-02-15 18:06:57,021 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1581790016717/joda-time-2.9.3.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/joda-time-2.9.3.jar
# 2020-02-15 18:06:57,028 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1581790016717/joda-time-2.9.3.jar /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/joda-time-2.9.3.jar' failed 1 with: ln: failed to create symbolic link '/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/joda-time-2.9.3.jar': Protocol error
#
# 2020-02-15 18:06:57,028 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1581790016717/joda-time-2.9.3.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/joda-time-2.9.3.jar
# 2020-02-15 18:06:57,028 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp183433602/tmp-1983838165/joda-time-2.9.3.jar as file:/tmp/hadoop-root/mapred/local/1581790016717/joda-time-2.9.3.jar
# 2020-02-15 18:06:57,087 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1581790016714/pig-0.17.0-core-h2.jar
# 2020-02-15 18:06:57,087 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1581790016715/automaton-1.11-8.jar
# 2020-02-15 18:06:57,088 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1581790016716/antlr-runtime-3.4.jar
# 2020-02-15 18:06:57,088 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1581790016717/joda-time-2.9.3.jar
# 2020-02-15 18:06:57,094 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2020-02-15 18:06:57,111 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2020-02-15 18:06:57,172 [Thread-15] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-02-15 18:06:57,176 [Thread-15] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-02-15 18:06:57,176 [Thread-15] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-02-15 18:06:57,177 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2020-02-15 18:06:57,231 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2020-02-15 18:06:57,232 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local123132353_0001_m_000000_0
# 2020-02-15 18:06:57,304 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-02-15 18:06:57,304 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-02-15 18:06:57,336 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2020-02-15 18:06:57,344 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 632
# Input split[0]:
#    Length = 632
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2020-02-15 18:06:57,369 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-02-15 18:06:57,369 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-02-15 18:06:57,479 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2020-02-15 18:06:57,479 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local123132353_0001_m_000000_0 is done. And is in the process of committing
# 2020-02-15 18:06:57,494 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2020-02-15 18:06:57,494 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task attempt_local123132353_0001_m_000000_0 is allowed to commit now
# 2020-02-15 18:06:57,501 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local123132353_0001_m_000000_0' to file:/tmp/temp183433602/tmp-1583098024/_temporary/0/task_local123132353_0001_m_000000
# 2020-02-15 18:06:57,502 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2020-02-15 18:06:57,503 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local123132353_0001_m_000000_0' done.
# 2020-02-15 18:06:57,507 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local123132353_0001_m_000000_0: Counters: 15
# 	File System Counters
# 		FILE: Number of bytes read=5801916
# 		FILE: Number of bytes written=12064790
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=18
# 		Map output records=11
# 		Input split bytes=402
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=274726912
# 	File Input Format Counters
# 		Bytes Read=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2020-02-15 18:06:57,507 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local123132353_0001_m_000000_0
# 2020-02-15 18:06:57,508 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2020-02-15 18:07:02,153 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:07:02,169 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:07:02,170 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2020-02-15 18:07:02,170 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2020-02-15 18:07:02,171 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:07:02,206 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:07:02,207 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:07:02,209 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:07:02,236 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (Hamilton)
# (Holcomb)
# (Garrett)
# (Fry)
# (Kinney)
# (Klein)
# (Diaz)
# (Guy)
# (Estes)
# (Jarvis)
# (Knight)

# %%
# !python3 grader.py
# Out:
# 2020-02-15 18:08:03,434 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2020-02-15 18:08:04,572 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-02-15 18:08:04,901 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - session.id is deprecated. Instead, use dfs.metrics.session-id
# 2020-02-15 18:08:04,902 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Initializing JVM Metrics with processName=JobTracker, sessionId=
# 2020-02-15 18:08:04,936 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-02-15 18:08:04,940 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2020-02-15 18:08:04,956 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.submit.replication is deprecated. Instead, use mapreduce.client.submit.file.replication
# 2020-02-15 18:08:05,163 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker.http.address is deprecated. Instead, use mapreduce.jobtracker.http.address
# 2020-02-15 18:08:05,179 [JobControl] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:08:05,215 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2020-02-15 18:08:05,286 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-02-15 18:08:05,375 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-02-15 18:08:05,423 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-02-15 18:08:05,581 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local1175245669_0001
# 2020-02-15 18:08:05,888 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1581790085702/pig-0.17.0-core-h2.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/pig-0.17.0-core-h2.jar
# 2020-02-15 18:08:05,930 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1581790085702/pig-0.17.0-core-h2.jar /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/pig-0.17.0-core-h2.jar' failed 1 with: ln: failed to create symbolic link '/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/pig-0.17.0-core-h2.jar': Protocol error
#
# 2020-02-15 18:08:05,930 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1581790085702/pig-0.17.0-core-h2.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/pig-0.17.0-core-h2.jar
# 2020-02-15 18:08:05,930 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp-949630849/tmp-1384060534/pig-0.17.0-core-h2.jar as file:/tmp/hadoop-root/mapred/local/1581790085702/pig-0.17.0-core-h2.jar
# 2020-02-15 18:08:05,988 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1581790085703/automaton-1.11-8.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/automaton-1.11-8.jar
# 2020-02-15 18:08:06,004 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1581790085703/automaton-1.11-8.jar /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/automaton-1.11-8.jar' failed 1 with: ln: failed to create symbolic link '/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/automaton-1.11-8.jar': Protocol error
#
# 2020-02-15 18:08:06,004 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1581790085703/automaton-1.11-8.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/automaton-1.11-8.jar
# 2020-02-15 18:08:06,004 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp-949630849/tmp-806038735/automaton-1.11-8.jar as file:/tmp/hadoop-root/mapred/local/1581790085703/automaton-1.11-8.jar
# 2020-02-15 18:08:06,006 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1581790085704/antlr-runtime-3.4.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/antlr-runtime-3.4.jar
# 2020-02-15 18:08:06,019 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1581790085704/antlr-runtime-3.4.jar /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/antlr-runtime-3.4.jar' failed 1 with: ln: failed to create symbolic link '/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/antlr-runtime-3.4.jar': Protocol error
#
# 2020-02-15 18:08:06,019 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1581790085704/antlr-runtime-3.4.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/antlr-runtime-3.4.jar
# 2020-02-15 18:08:06,019 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp-949630849/tmp1270546430/antlr-runtime-3.4.jar as file:/tmp/hadoop-root/mapred/local/1581790085704/antlr-runtime-3.4.jar
# 2020-02-15 18:08:06,021 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Creating symlink: /tmp/hadoop-root/mapred/local/1581790085705/joda-time-2.9.3.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/joda-time-2.9.3.jar
# 2020-02-15 18:08:06,030 [JobControl] WARN  org.apache.hadoop.fs.FileUtil - Command 'ln -s /tmp/hadoop-root/mapred/local/1581790085705/joda-time-2.9.3.jar /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/joda-time-2.9.3.jar' failed 1 with: ln: failed to create symbolic link '/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/joda-time-2.9.3.jar': Protocol error
#
# 2020-02-15 18:08:06,030 [JobControl] WARN  org.apache.hadoop.mapred.LocalDistributedCacheManager - Failed to create symlink: /tmp/hadoop-root/mapred/local/1581790085705/joda-time-2.9.3.jar <- /datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/joda-time-2.9.3.jar
# 2020-02-15 18:08:06,030 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - Localized file:/tmp/temp-949630849/tmp-81150426/joda-time-2.9.3.jar as file:/tmp/hadoop-root/mapred/local/1581790085705/joda-time-2.9.3.jar
# 2020-02-15 18:08:06,145 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1581790085702/pig-0.17.0-core-h2.jar
# 2020-02-15 18:08:06,145 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1581790085703/automaton-1.11-8.jar
# 2020-02-15 18:08:06,145 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1581790085704/antlr-runtime-3.4.jar
# 2020-02-15 18:08:06,146 [JobControl] INFO  org.apache.hadoop.mapred.LocalDistributedCacheManager - file:/tmp/hadoop-root/mapred/local/1581790085705/joda-time-2.9.3.jar
# 2020-02-15 18:08:06,155 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2020-02-15 18:08:06,157 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2020-02-15 18:08:06,253 [Thread-14] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-02-15 18:08:06,256 [Thread-14] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-02-15 18:08:06,258 [Thread-14] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-02-15 18:08:06,258 [Thread-14] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-02-15 18:08:06,260 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2020-02-15 18:08:06,362 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2020-02-15 18:08:06,363 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1175245669_0001_m_000000_0
# 2020-02-15 18:08:06,489 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-02-15 18:08:06,490 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-02-15 18:08:06,518 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2020-02-15 18:08:06,525 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 632
# Input split[0]:
#    Length = 632
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2020-02-15 18:08:06,552 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-02-15 18:08:06,552 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-02-15 18:08:06,750 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2020-02-15 18:08:06,771 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1175245669_0001_m_000000_0 is done. And is in the process of committing
# 2020-02-15 18:08:06,797 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2020-02-15 18:08:06,797 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task attempt_local1175245669_0001_m_000000_0 is allowed to commit now
# 2020-02-15 18:08:06,836 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local1175245669_0001_m_000000_0' to file:/datalake/AGD Lab/evaluacion-final-Farid1994/02-pig-50/q12-10/output/_temporary/0/task_local1175245669_0001_m_000000
# 2020-02-15 18:08:06,845 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2020-02-15 18:08:06,846 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1175245669_0001_m_000000_0' done.
# 2020-02-15 18:08:06,852 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1175245669_0001_m_000000_0: Counters: 15
# 	File System Counters
# 		FILE: Number of bytes read=5801916
# 		FILE: Number of bytes written=12068677
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=18
# 		Map output records=11
# 		Input split bytes=402
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=294125568
# 	File Input Format Counters
# 		Bytes Read=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2020-02-15 18:08:06,853 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1175245669_0001_m_000000_0
# 2020-02-15 18:08:06,853 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2020-02-15 18:08:11,714 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:08:11,734 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:08:11,734 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2020-02-15 18:08:11,734 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2020-02-15 18:08:11,738 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:08:11,774 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:08:11,776 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 18:08:11,778 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
