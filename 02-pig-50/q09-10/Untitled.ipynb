# %%
# %reload_ext bigdata
# %pig_start
# %timeout 300

# %%
# %%pig
# u = LOAD 'data.csv' USING PigStorage(',')
#     AS (c1:int,
#         c2:CHARARRAY,
#         c3:CHARARRAY,
#         c4:CHARARRAY,
#         c5:CHARARRAY,
#         c6:int);
# result= FOREACH u GENERATE CONCAT($1,'@',$2);
# Out:
#  u = LOAD 'data.csv' USING PigStorage(',')
#     AS (c1:int,
#         c2:CHARARRAY,
#         c3:CHARARRAY,
#         c4:CHARARRAY,
#         c5:CHARARRAY,
#         c6:int);
#  result= FOREACH u GENERATE CONCAT($1,'@',$2);

# %%
# %%pig
# DUMP result;
# Out:
#  DUMP result;
# 2020-02-15 17:20:01,414 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 17:20:01,468 [JobControl] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2020-02-15 17:20:01,475 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-02-15 17:20:01,529 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-02-15 17:20:01,532 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-02-15 17:20:01,543 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local868113403_0003
# ...

# %%
# !python3 grader.py
# Out:
# 2020-02-15 17:21:53,597 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2020-02-15 17:21:54,679 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-02-15 17:21:55,015 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - session.id is deprecated. Instead, use dfs.metrics.session-id
# 2020-02-15 17:21:55,016 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Initializing JVM Metrics with processName=JobTracker, sessionId=
# 2020-02-15 17:21:55,051 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# ...
